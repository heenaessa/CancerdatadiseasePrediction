# %% [markdown]
# <a href="https://colab.research.google.com/github/heenaessa/CancerdatadiseasePrediction/blob/main/Minor_Project(cancer_patients_datasets_df).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cancer Disease Prediction System Using Machine Learning**
# The problem statement is that we need to predict those people who are prone to have Cancer Disease with respect to different parameters such as their Age, Gender, Alcohol Use, Genetic Risk and Smoking.

# %% [markdown]
# # **Importing Libraries**

# %%
# Importing useful Libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-whitegrid")

# %% [markdown]
# # **Importing Data**

# %%
# importing datasets
import pandas as pd
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f695c20-6fb2-49d9-afb1-64964d6c94dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f695c20-6fb2-49d9-afb1-64964d6c94dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cancer_patients_datasets.csv to cancer_patients_datasets.csv

# %%
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# User uploaded file "cancer_patients_datasets.csv" with length 58579 bytes

# %%
uploaded
# Out:
# {'cancer_patients_datasets.csv': b'Patient Id,Age,Gender,Air Pollution,Alcohol use,Dust Allergy,OccuPational Hazards,Genetic Risk,chronic Lung Disease,Balanced Diet,Obesity,Smoking,Passive Smoker,Chest Pain,Coughing of Blood,Fatigue,Weight Loss,Shortness of Breath,Wheezing,Swallowing Difficulty,Clubbing of Finger Nails,Frequent Cold,Dry Cough,Snoring,Level\r\nP1,33,1,2,4,5,4,3,2,2,4,3,2,2,4,3,4,2,2,3,1,2,3,4,Low\r\nP10,17,1,3,1,5,3,4,2,2,2,2,4,2,3,1,3,7,8,6,2,1,7,2,Medium\r\nP100,35,1,4,5,6,5,5,4,6,7,2,3,4,8,8,7,9,2,1,4,6,7,2,High\r\nP1000,37,1,7,7,7,7,6,7,7,7,7,7,7,8,4,2,3,1,4,5,6,7,5,High\r\nP101,46,1,6,8,7,7,7,6,7,7,8,7,7,9,3,2,4,1,4,2,4,2,3,High\r\nP102,35,1,4,5,6,5,5,4,6,7,2,3,4,8,8,7,9,2,1,4,6,7,2,High\r\nP103,52,2,2,4,5,4,3,2,2,4,3,2,2,4,3,4,2,2,3,1,2,3,4,Low\r\nP104,28,2,3,1,4,3,2,3,4,3,1,4,3,1,3,2,2,4,2,2,3,4,3,Low\r\nP105,35,2,4,5,6,5,6,5,5,5,6,6,6,5,1,4,3,2,4,6,2,4,1,Medium\r\nP106,46,1,2,3,4,2,4,3,3,3,2,3,4,4,1,2,4,6,5,4,2,1,5,Medium\r\nP107,44,1,6,7,7,7,7,6,7,7,7,8,7,7,5
# ...

# %%
import io

# %%
cancer_patients_datasets_df=pd.read_csv(io.StringIO(uploaded['cancer_patients_datasets.csv'].decode('utf-8')))

# %%
cancer_patients_datasets_df.head()
# Out:
#   Patient Id  Age  Gender  ...  Dry Cough  Snoring   Level
# 0         P1   33       1  ...          3        4     Low
# 1        P10   17       1  ...          7        2  Medium
# 2       P100   35       1  ...          7        2    High
# 3      P1000   37       1  ...          7        5    High
# 4       P101   46       1  ...          2        3    High
#
# [5 rows x 25 columns]

# %%
cancer_patients_datasets_df.tail()
# Out:
#     Patient Id  Age  Gender  ...  Dry Cough  Snoring  Level
# 995       P995   44       1  ...          5        3   High
# 996       P996   37       2  ...          1        4   High
# 997       P997   25       2  ...          7        2   High
# 998       P998   18       2  ...          2        3   High
# 999       P999   47       1  ...          7        2   High
#
# [5 rows x 25 columns]

# %% [markdown]
# # **Check Columns**

# %%
cancer_patients_datasets_df.columns
# Out:
# Index(['Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
#@title
print(cancer_patients_datasets_df.to_string())
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  Passive Smoker  Chest Pain  Coughing of Blood  Fatigue  Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0           P1   33       1              2            4             5                     4             3                     2              2        4        3               2           2                  4        3            4                    2         2                      3                         1              2          3        4     Low
# ...

# %%
len(cancer_patients_datasets_df)
# Out:
# 1000

# %%
cancer_patients_datasets_df.shape
# Out:
# (1000, 25)

# %%
cancer_patients_datasets_df.size
# Out:
# 25000

# %%
cancer_patients_datasets_df.count()
# Out:
# Patient Id                  1000
# Age                         1000
# Gender                      1000
# Air Pollution               1000
# Alcohol use                 1000
# Dust Allergy                1000
# OccuPational Hazards        1000
# Genetic Risk                1000
# chronic Lung Disease        1000
# Balanced Diet               1000
# Obesity                     1000
# Smoking                     1000
# Passive Smoker              1000
# Chest Pain                  1000
# Coughing of Blood           1000
# Fatigue                     1000
# Weight Loss                 1000
# Shortness of Breath         1000
# Wheezing                    1000
# Swallowing Difficulty       1000
# Clubbing of Finger Nails    1000
# Frequent Cold               1000
# Dry Cough                   1000
# Snoring                     1000
# Level                       1000
# dtype: int64

# %% [markdown]
# # **Checking missing values in the dataset**

# %%
# Checking for messing values
cancer_patients_datasets_df.isna().sum()
# Out:
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %% [markdown]
# # **Information of Dataset**

# %%
cancer_patients_datasets_df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Id                1000 non-null   object
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   int64
#  3   Air Pollution             1000 non-null   int64
#  4   Alcohol use               1000 non-null   int64
#  5   Dust Allergy              1000 non-null   int64
#  6   OccuPational Hazards      1000 non-null   int64
#  7   Genetic Risk              1000 non-null   int64
#  8   chronic Lung Disease      1000 non-null   int64
#  9   Balanced Diet             1000 non-null   int64
#  10  Obesity                   1000 non-null   int64
#  11  Smoking                   1000 non-null   int64
#  12  Passive Smoker            1000 non-null   int64
#  13  Chest Pain                1000 non-null   int64
# ...

# %% [markdown]
# Data is already clean, no null values so let's analyse further

# %% [markdown]
# # **Statistics of data**

# %%
cancer_patients_datasets_df.describe().T
# Out:
#                            count    mean        std  ...   50%   75%   max
# Age                       1000.0  37.174  12.005493  ...  36.0  45.0  73.0
# Gender                    1000.0   1.402   0.490547  ...   1.0   2.0   2.0
# Air Pollution             1000.0   3.840   2.030400  ...   3.0   6.0   8.0
# Alcohol use               1000.0   4.563   2.620477  ...   5.0   7.0   8.0
# Dust Allergy              1000.0   5.165   1.980833  ...   6.0   7.0   8.0
# OccuPational Hazards      1000.0   4.840   2.107805  ...   5.0   7.0   8.0
# Genetic Risk              1000.0   4.580   2.126999  ...   5.0   7.0   7.0
# chronic Lung Disease      1000.0   4.380   1.848518  ...   4.0   6.0   7.0
# Balanced Diet             1000.0   4.491   2.135528  ...   4.0   7.0   7.0
# Obesity                   1000.0   4.465   2.124921  ...   4.0   7.0   7.0
# Smoking                   1000.0   3.948   2.495902  ...   3.0   7.0   8.0
# ...

# %% [markdown]
# Heatmap for cancer patients datasets.
# Heatmap contains values representing various shades of the same colour for each value to be plotted and the darker shades of the chart represent higher values than the lighter shade or a very different value a completely different colour is also used here.

# %% [markdown]
# # **Heatmap for cancer patients datasets**

# %%
fig = plt.figure(figsize = (13,8))
sns.heatmap(cancer_patients_datasets_df.corr(),cmap='coolwarm',annot=True);
#plt.figure(figsize=(16,9))
 #sns.heatmap(cancer_patients_datasets_df.corr(), annot = True)

# %% [markdown]
# **Positive Correlation (0.5)**
#  'Age', 'Gender', 'Air Pollution', 'Alcohol use','OccuPational Hazards', 'Genetic Risk','chronic Lung Disease', 'Balanced Diet', 'Obesity','Passive Smoker', 'Chest Pain', 'Coughing of Blood'
#
# **Negative Correlation(-0.2)**
# 'Fatigue', 'Weight Loss', 'Shortness of Breath', 'Wheezing','Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold', 'Dry Cough', 'Snoring', mixed
#
# **No Correlation (0.0)**
# Mixed

# %% [markdown]
# # **Histplot of Data in Age**

# %%
fig, ax = plt.subplots()
hist = ax.hist(x = cancer_patients_datasets_df["Age"]);

# %% [markdown]
# # **Histplot of Data in Level**

# %%
fig, ax=plt.subplots()#Required outside of function. This needs to be activated first when plotting in every code block
plot=sns.countplot(data=cancer_patients_datasets_df, x='Level', palette=['yellow','orange','green'])#Count plot
#Plotter(plot, 'Level', 'Count', legend=None, save=True, save_name='Level Count.png')#Plotter function for aesthetics
#plot

# %% [markdown]
# As we can see the data is fairly balanced. Why don't we break it down further by gender. This boxplot shows the number of patients according to their age.

# %% [markdown]
# # **Boxplot of Dataset in gender**

# %%
#Required outside of function. This needs to be activated first when plotting in every code block
fig, ax = plt.subplots()

#Count plot
plot = sns.countplot(data = cancer_patients_datasets_df, x='Level', hue='Gender', palette=['orange','green'])

# %% [markdown]
# We have a higher representation of gender one than gender two. Lets start by looking to see if there is a correlation between some of the data. We can start with alcohol use and fatique and see if the level of cancer is related to them.

# %% [markdown]
# # **View of columns of data**

# %%
cancer_patients_datasets_df.columns
# Out:
# Index(['Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %% [markdown]
# # **Unique value of data**

# %%
cancer_patients_datasets_df.nunique(axis=0)
# Out:
# Patient Id                  1000
# Age                           40
# Gender                         2
# Air Pollution                  8
# Alcohol use                    8
# Dust Allergy                   8
# OccuPational Hazards           8
# Genetic Risk                   7
# chronic Lung Disease           7
# Balanced Diet                  7
# Obesity                        7
# Smoking                        8
# Passive Smoker                 8
# Chest Pain                     9
# Coughing of Blood              9
# Fatigue                        8
# Weight Loss                    8
# Shortness of Breath            8
# Wheezing                       8
# Swallowing Difficulty          8
# Clubbing of Finger Nails       9
# Frequent Cold                  7
# Dry Cough                      7
# Snoring                        7
# Level                          3
# dtype: int64

# %% [markdown]
# # **For Patients who are over age 50**

# %%
cancer_patients_datasets_df["Age"] > 50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Age, Length: 1000, dtype: bool

# %%
cancer_patients_datasets_df[cancer_patients_datasets_df["Age"] > 50]
# Out:
#     Patient Id  Age  Gender  ...  Dry Cough  Snoring   Level
# 6         P103   52       2  ...          3        4     Low
# 11        P108   64       2  ...          1        4    High
# 15        P111   73       1  ...          6        2  Medium
# 21        P117   53       2  ...          7        2    High
# 22        P118   62       1  ...          2        3    High
# ..         ...  ...     ...  ...        ...      ...     ...
# 950       P954   55       1  ...          5        2     Low
# 959       P962   62       1  ...          4        2  Medium
# 968       P970   52       2  ...          2        5  Medium
# 969       P971   52       1  ...          4        2  Medium
# 979       P980   53       1  ...          6        2     Low
#
# [134 rows x 25 columns]

# %% [markdown]
# # **Cancer found in people age over 50.**

# %%
cancer_over50 = cancer_patients_datasets_df[cancer_patients_datasets_df["Age"] > 50]
cancer_over50.head()
# Out:
#    Patient Id  Age  Gender  ...  Dry Cough  Snoring   Level
# 6        P103   52       2  ...          3        4     Low
# 11       P108   64       2  ...          1        4    High
# 15       P111   73       1  ...          6        2  Medium
# 21       P117   53       2  ...          7        2    High
# 22       P118   62       1  ...          2        3    High
#
# [5 rows x 25 columns]

# %% [markdown]
# 5 rows × 25 columns.

# %%
len(cancer_patients_datasets_df), len(cancer_over50)
# Out:
# (1000, 134)

# %% [markdown]
# There are only 134 patients who are Over 50 so we analyse the entire data irresespective of age to achieve fruitfull results later.

# %% [markdown]
# # **Histogram over age 50.**

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots()
hist = ax.hist(x = cancer_over50["Age"]);

# %% [markdown]
# # **Over 50 age level plot.**

# %%
fig, ax = plt.subplots()

histt = ax.hist(x = cancer_over50["Level"], bins = 10, color ='green')

ax.set(xlabel = "Level", ylabel = "Count");

# %%
sns.scatterplot(x='Age',y='Gender',data=cancer_patients_datasets_df,color='green')
plt.show()

# %% [markdown]
# # **Over 50 age relaltion between alcohol use, genetic risk, smoking and gender.**

# %%
# Making Subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols= 2, figsize=(10, 10))

# Adding Data to the plot
scatter = ax1.scatter(x = cancer_over50["Age"], y = cancer_over50["Alcohol use"], cmap = "winter")

# For Plot ax1
ax1.set(title = "Age with respect to Alcohol Use", 
        xlabel = "Age", 
        ylabel = "Alcohol Use")
ax1.axhline(cancer_over50["Alcohol use"].mean(),
           linestyle = "--");
ax1.set_xlim([50, 80])
ax1.set_ylim([0, 8.5])

# For Plot ax2
scatter = ax2.scatter(x = cancer_over50["Age"], y = cancer_over50["Genetic Risk"])
ax2.set(title = "Age with respect to Genetic Risk", xlabel = "Age", ylabel = "Genetic Risk")
ax2.axhline(cancer_over50["Genetic Risk"].mean(),
           linestyle = "--");
ax2.set_xlim([50, 80])
ax2.set_ylim([0, 7.5])

# For Plot ax3
scatter = ax3.scatter(x = cancer_over50["Age"], y = cancer_over50["Smoking"])
ax3.set(title = "Age with respect to Smoking", xlabel = "Age", ylabel = "Smoking")
ax3.axhline(cancer_over50["Smoking"].mean(),
           linestyle = "--");
ax3.set_xlim([50, 80])
ax3.set_ylim([0, 8.5])

# For Plot ax4
scatter = ax4.scatter(x = cancer_over50["Gender"], y = cancer_over50["Alcohol use"])
ax4.set(title = "Age with respect to Alcohol Use", xlabel = "Gender", ylabel = "Alcohol Use")
ax4.axhline(cancer_over50["Alcohol use"].mean(),
           linestyle = "--");

# %% [markdown]
# # **Recheking Dataset columns**

# %%
cancer_patients_datasets_df.columns
# Out:
# Index(['Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
cancer_patients_datasets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Id                1000 non-null   object
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   int64
#  3   Air Pollution             1000 non-null   int64
#  4   Alcohol use               1000 non-null   int64
#  5   Dust Allergy              1000 non-null   int64
#  6   OccuPational Hazards      1000 non-null   int64
#  7   Genetic Risk              1000 non-null   int64
#  8   chronic Lung Disease      1000 non-null   int64
#  9   Balanced Diet             1000 non-null   int64
#  10  Obesity                   1000 non-null   int64
#  11  Smoking                   1000 non-null   int64
#  12  Passive Smoker            1000 non-null   int64
#  13  Chest Pain                1000 non-null   int64
# ...

# %% [markdown]
# As we can see Level dtype is not int so first we replace it with numbers then into type int

# %% [markdown]
# # **Replacing Level into index number.**

# %%
cancer_patients_datasets_df["Level"].replace(["Low", "Medium", "High"], ["0", "1", "2"], inplace=True)

# %%
cancer_patients_datasets_df["Level"] = cancer_patients_datasets_df["Level"].astype(int)

# %% [markdown]
# # **Determining data type of each column**

# %%
cancer_patients_datasets_df.head().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Id                5 non-null      object
#  1   Age                       5 non-null      int64
#  2   Gender                    5 non-null      int64
#  3   Air Pollution             5 non-null      int64
#  4   Alcohol use               5 non-null      int64
#  5   Dust Allergy              5 non-null      int64
#  6   OccuPational Hazards      5 non-null      int64
#  7   Genetic Risk              5 non-null      int64
#  8   chronic Lung Disease      5 non-null      int64
#  9   Balanced Diet             5 non-null      int64
#  10  Obesity                   5 non-null      int64
#  11  Smoking                   5 non-null      int64
#  12  Passive Smoker            5 non-null      int64
#  13  Chest Pain                5 non-null      int64
# ...

# %% [markdown]
# Above entire data is in int.

# %% [markdown]
# Here, we need not to do normalization because our data is pretty straightforward for analysing.

# %% [markdown]
# # **Pie plot in terms of sizes(%) in level**

# %%
#@title 
sns.set(rc = {'figure.figsize': (10,7)})
labels = list(cancer_patients_datasets_df.Level.unique())
sizes = list(cancer_patients_datasets_df.Level.value_counts())

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct = '%1.2f%%', startangle = 55)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0855dd8e90>,
# ...
#  [Text(-0.5615972380405895, 0.9458374819307922, '0'),
#   Text(-0.4446023359911846, -1.0061454978437174, '1'),
#   Text(1.0999645489011007, 0.008831260430879617, '2')],
#  [Text(-0.30632576620395785, 0.5159113537804321, '36.50%'),
#   Text(-0.24251036508610063, -0.5488066351874822, '33.20%'),
#   Text(0.599980663036964, 0.004817051144116155, '30.30%')])

# %% [markdown]
# Plotting with respect to Age and Genetic Risk.

# %% [markdown]
# # **Plot b/w Age, Genetic Risk and Level**

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize = (10, 6));

scatter = ax.scatter(x = cancer_patients_datasets_df["Age"], 
                     y = cancer_patients_datasets_df["Genetic Risk"],
                     c = cancer_patients_datasets_df["Level"],
                     cmap = "winter")

ax.set(xlabel = "Age", 
       ylabel = "Genetic Risk");

ax.legend(*scatter.legend_elements(), title = "Level");

ax.axhline(cancer_patients_datasets_df["Level"].mean(),
           linestyle = "--");

# %% [markdown]
# # **Plot b/w Alcohol use and Fatigue**

# %%
fig, ax=plt.subplots()#Required outside of function. This needs to be activated first when plotting in every code block
plot=sns.scatterplot(data=cancer_patients_datasets_df, x='Alcohol use',y='Fatigue', hue='Level', palette=['darkblue','darkred','darkgreen'], s=100, marker='o')#Count plot

# %% [markdown]
# There is clearly two different clusters for low and high levels by alcohol use and fatique while medium is a combination of both. Is there a difference by age and level of cancer?

# %% [markdown]
# # **Boxplot in Data**

# %%
fig, ax=plt.subplots()#Required outside of function. This needs to be activated first when plotting in every code block
plot=sns.boxplot(data=cancer_patients_datasets_df, x='Level', y='Age', palette=['yellow','orange','green'])#Count plot

# %% [markdown]
# Looking at the box-plot, age is not to important on level of cancer. Though there are a lot of variables to look at we can we can just find the most important ones by using the SelectKBest Algorithm with ANOVA F-ratio statistic.

# %% [markdown]
# # **Finding Outlier in all boxplot**

# %%
plt.figure(figsize=(40,20))
sns.boxplot(data=cancer_patients_datasets_df)
plt.show()

# %%
Q1,Q3=cancer_patients_datasets_df['Age'].quantile([.25,.75])
IQR=Q3-Q1
LL=Q1-1.5*(IQR)
UL=Q1+1.5*(IQR)

print(IQR)
# Out:
# 17.25

# %% [markdown]
# # **Plot Dataset in terms of dieseas**

# %%
cancer_patients_datasets_df.plot.kde(figsize = (24,15));

# %% [markdown]
# Feature Selection
# This method will generate the F-ratio scores of all features and we can determine which ones to use for machine learning.

# %% [markdown]
# # **Importing Feature Section**

# %%
#@title
from sklearn.feature_selection import SelectKBest #Feature Selector
from sklearn.feature_selection import f_classif #F-ratio statistic for categorical values

# %% [markdown]
# Here, we can also use plotter by definig.

# %% [markdown]
# # **#Feature Selection**

# %%
#Feature Selection
X=cancer_patients_datasets_df.drop(['Level','Patient Id'], axis=1)
Y=cancer_patients_datasets_df['Level']
bestfeatures = SelectKBest(score_func=f_classif, k='all')
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Feature','Score']  #naming the dataframe columns

#Visualize the feature scores
fig, ax=plt.subplots(figsize=(7,7))
plot=sns.barplot(data=featureScores, x='Score', y='Feature', palette='viridis',linewidth=0.5, saturation=2, orient='h')
#Plotter(plot, 'Score', 'Feature', legend=False, save=True, save_name='Feature Importance.png')#Plotter function for aesthetics
#plot

# %% [markdown]
# We will take all the features that scored more than 200 as they show the least redundancy.

# %% [markdown]
# # **Selection Method**

# %%
#Selection method
selection=featureScores[featureScores['Score']>=200]#Selects features that scored more than 200
selection=list(selection['Feature'])#Generates the features into a list
selection.append('Level')#Adding the Level string to be used to make new data frame
new_cancer=cancer_patients_datasets_df[selection] #New dataframe with selected features
new_cancer.head() #Lets take a look at the first 5
# Out:
#    Air Pollution  Alcohol use  Dust Allergy  ...  Coughing of Blood  Fatigue  Level
# 0              2            4             5  ...                  4        3      0
# 1              3            1             5  ...                  3        1      1
# 2              4            5             6  ...                  8        8      2
# 3              7            7             7  ...                  8        4      2
# 4              6            8             7  ...                  9        3      2
#
# [5 rows x 14 columns]

# %% [markdown]
# As we can see, 13 features were selected and we created a new data frame to account for them. We can now start the process of preprocessing for machine learning application.

# %%
new_cancer.columns
# Out:
# Index(['Air Pollution', 'Alcohol use', 'Dust Allergy', 'OccuPational Hazards',
#        'Genetic Risk', 'chronic Lung Disease', 'Balanced Diet', 'Obesity',
#        'Smoking', 'Passive Smoker', 'Chest Pain', 'Coughing of Blood',
#        'Fatigue', 'Level'],
#       dtype='object')

# %%
np.array([cancer_patients_datasets_df["Gender"][:10]])
# Out:
# array([[1, 1, 1, 1, 1, 1, 2, 2, 2, 1]])

# %% [markdown]
# # **Number of Male & Females**

# %%
male = 0
female = 0
for i in cancer_patients_datasets_df["Gender"]:
    if i == 1:
        male += 1
    elif i == 2:
        female += 1
f"Number of Male: {male}, Number of females: {female}"
# Out:
# 'Number of Male: 598, Number of females: 402'

# %% [markdown]
# # **Determining proportion of Gender in the dataset**

# %%
cancer_patients_datasets_df.Gender.value_counts()
# Out:
# 1    598
# 2    402
# Name: Gender, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,8))
plt.pie(x=cancer_patients_datasets_df["Gender"].value_counts(), 
        colors=["skyblue","pink"], 
        labels=["Male","Female"], 
        shadow = True, 
        autopct="%1.2f%%", 
        explode = (0, 0.1)
        )
plt.show()

# %% [markdown]
# # **Head table For Male**

# %%
# Make a histogram here
cancer_patient_male = cancer_patients_datasets_df[cancer_patients_datasets_df["Gender"] == 1]
cancer_patient_male.head()
# Out:
#   Patient Id  Age  Gender  ...  Dry Cough  Snoring  Level
# 0         P1   33       1  ...          3        4      0
# 1        P10   17       1  ...          7        2      1
# 2       P100   35       1  ...          7        2      2
# 3      P1000   37       1  ...          7        5      2
# 4       P101   46       1  ...          2        3      2
#
# [5 rows x 25 columns]

# %% [markdown]
# # **Head table For Female**

# %%
cancer_patient_female = cancer_patients_datasets_df[cancer_patients_datasets_df["Gender"] == 2]
cancer_patient_female.head()
# Out:
#    Patient Id  Age  Gender  ...  Dry Cough  Snoring  Level
# 6        P103   52       2  ...          3        4      0
# 7        P104   28       2  ...          4        3      0
# 8        P105   35       2  ...          4        1      1
# 11       P108   64       2  ...          1        4      2
# 12       P109   39       2  ...          5        6      1
#
# [5 rows x 25 columns]

# %%
sns.displot(cancer_patient_male, bins=82, kde=True);

# %%
sns.displot(cancer_patient_female, bins=100, kde=True);

# %%
fig, ax = plt.subplots()
scatter = ax.scatter(x = cancer_patient_male["Alcohol use"], y = cancer_patient_male["Smoking"])
# cancer_patient_male.plot(x = cancer_patient_male["Alcohol use"], y = cancer_patient_male["Age"], kind = "scatter");

# %%
fig, ax = plt.subplots()
scatter = ax.scatter(x = cancer_patient_female["Alcohol use"], y = cancer_patient_female["Smoking"]);

# %%
plt.subplot(122)
plt.title('subplot: 122')
sns.scatterplot(data = cancer_patient_male, x = 'Genetic Risk', y = 'Smoking', hue = 'Level')

# %%
fig, ax = plt.subplots()
cancer_patient_male.plot(kind = "bar", x = "Genetic Risk", y = "Smoking", ax = ax);

# %%
fig, ax = plt.subplots()
cancer_patient_female.plot(kind = "bar", x = "Genetic Risk", y = "Smoking", ax = ax);

# %%
fig, ax = plt.subplots()
cancer_patient_male.plot(kind = "bar", x = "chronic Lung Disease", y = "Obesity", ax = ax);

# %%
fig, ax = plt.subplots()
cancer_patient_female.plot(kind = "bar", x = "chronic Lung Disease", y = "Obesity", ax = ax);

# %%
len(cancer_patient_male), len(cancer_patient_female)
# Out:
# (598, 402)

# %%
fig, ax = plt.subplots()
cancer_patients_datasets_df.plot(kind = "bar", x = "Gender", y = "Age", ax = ax);

# %%
cancer_patients_datasets_df.head()
# Out:
#   Patient Id  Age  Gender  ...  Dry Cough  Snoring  Level
# 0         P1   33       1  ...          3        4      0
# 1        P10   17       1  ...          7        2      1
# 2       P100   35       1  ...          7        2      2
# 3      P1000   37       1  ...          7        5      2
# 4       P101   46       1  ...          2        3      2
#
# [5 rows x 25 columns]

# %% [markdown]
# # **Droping the Patients Id column.**

# %% [markdown]
# # **Histograms w/o Patient id and each variable**

# %%
cancer_patients_datasets_df1 = cancer_patients_datasets_df.drop(labels=['Patient Id'],axis=1,inplace=False)
Patient_Id = cancer_patients_datasets_df['Patient Id']
col = cancer_patients_datasets_df1.columns
for i in col:
    figure = plt.figure(figsize=(12,10))
    sns.countplot( x=i,hue='Gender',data=cancer_patients_datasets_df1)
    plt.show()

# %%
cancer_patients_datasets_df.drop(["Patient Id"], axis = 1, inplace= True)

# %%
cancer_patients_datasets_df.head()
# Out:
#    Age  Gender  Air Pollution  ...  Dry Cough  Snoring  Level
# 0   33       1              2  ...          3        4      0
# 1   17       1              3  ...          7        2      1
# 2   35       1              4  ...          7        2      2
# 3   37       1              7  ...          7        5      2
# 4   46       1              6  ...          2        3      2
#
# [5 rows x 24 columns]

# %%
# pair plot of sample feature
sns.pairplot(new_cancer, hue = 'Level', 
             vars = ['Air Pollution', 'Alcohol use', 'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease', 'Balanced Diet', 'Obesity','Smoking', 'Passive Smoker', 'Chest Pain', 'Coughing of Blood',
       'Fatigue'] )

# %%
# pair plot of sample feature
sns.pairplot(cancer_patients_datasets_df, hue = 'Gender', 
             vars = ['Age', 'Alcohol use', 'Genetic Risk', 'Smoking', 'chronic Lung Disease'] )

# %% [markdown]
# Fitting the model/algorithm and use it to make predictions on our data.

# %% [markdown]
# # **Data Splitting**

# %% [markdown]
# Y = Level
#
# X = Rest of the data

# %% [markdown]
# X data after droping level.

# %%
X.head()
# Out:
#    Age  Gender  Air Pollution  ...  Frequent Cold  Dry Cough  Snoring
# 0   33       1              2  ...              2          3        4
# 1   17       1              3  ...              1          7        2
# 2   35       1              4  ...              6          7        2
# 3   37       1              7  ...              6          7        5
# 4   46       1              6  ...              4          2        3
#
# [5 rows x 23 columns]

# %%
Y.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    2
# 4    2
# Name: Level, dtype: int64

# %% [markdown]
# Y as Level.

# %%
# split dataset into tain and test datset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(new_cancer.drop(['Level'], axis=1), new_cancer['Level'],test_size=0.25, random_state=0)

# %%
len(X_train), len(X_test)
# Out:
# (750, 250)

# %%
len(y_train), len(y_test)
# Out:
# (750, 250)

# %%
#Checking the shapes
print("X_train shape :",X_train.shape)
print("y_train shape :",y_train.shape)
print("X_test shape :",X_test.shape)
print("y_test shape :",y_test.shape)
# Out:
# X_train shape : (750, 13)
# y_train shape : (750,)
# X_test shape : (250, 13)
# y_test shape : (250,)

# %%
from sklearn.metrics import accuracy_score # For accuracy score

# %%
accuracy_list = []

# %% [markdown]
# # **Scaling data**

# %%
# Featrure Scalling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# First we use Support Vector Machine Estimator.

# %% [markdown]
# # **Model 1. Support Vector Machine**

# %%
# Support Vector Machine
from sklearn.svm import SVC
svc_model = SVC()#Training the model
svc_model.fit(X_train, y_train) #Training the model
svc_prediction = svc_model.predict(X_test) #Testing the model
svc_accuracy = (round(accuracy_score(svc_prediction, y_test), 4) * 100) #Measure accuracy of the model
accuracy_list.append(svc_accuracy)
#print("Accuracy obtained by Support Vector Machine Classifier:", svc_accuracy)

# %% [markdown]
# # **Testing the predicted Model**

# %%
accuracy_score(y_test, svc_prediction)
# Out:
# 1.0

# %% [markdown]
# # **Classification Report of SVM**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score #Importing Classification Report
print(classification_report(y_test, svc_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#            1       1.00      1.00      1.00        74
#            2       1.00      1.00      1.00        91
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %% [markdown]
# # **Confusion Matrix**

# %%
cm = confusion_matrix(y_test, svc_prediction)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# # **KNN**

# %%
# K – Nearest Neighbor Classifier
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=6)
knn_model.fit(X_train, y_train)
knn_prediction = knn_model.predict(X_test)
knn_accuracy = (round(accuracy_score(knn_prediction, y_test), 4) * 100) 
accuracy_list.append(knn_accuracy)
#print("Accuracy obtained by K-Nearest Neighbor Classifier:", knn_accuracy)

# %% [markdown]
# # **Testing the predicted Model**

# %%
accuracy_score(y_test, knn_prediction)
# Out:
# 1.0

# %% [markdown]
# # **Classification Report of knn**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(classification_report(y_test, knn_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#            1       1.00      1.00      1.00        74
#            2       1.00      1.00      1.00        91
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %% [markdown]
# # **Confusion matrix**

# %%
cm = confusion_matrix(y_test, knn_prediction)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# # **DT**

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(criterion="entropy", max_depth=2)
dt_model.fit(X_train, y_train)
dt_prediction = dt_model.predict(X_test)
dt_accuracy = (round(accuracy_score(dt_prediction, y_test), 4) * 100) 
accuracy_list.append(dt_accuracy)
#print("Accuracy obtained by Decision Tree Classifier:", dt_accuracy)

# %% [markdown]
# # **Testing the predicted Model**

# %%
accuracy_score(y_test, dt_prediction)
# Out:
# 0.772

# %% [markdown]
# # **Classification Report**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(classification_report(y_test, dt_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.92      0.74        85
#            1       1.00      0.36      0.53        74
#            2       0.91      0.97      0.94        91
#
#     accuracy                           0.77       250
#    macro avg       0.84      0.75      0.74       250
# weighted avg       0.84      0.77      0.75       250

# %% [markdown]
# # **Confusion matrix**

# %%
cm = confusion_matrix(y_test, dt_prediction)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# # **RF**

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_prediction = rf_model.predict(X_test)
rf_accuracy = (round(accuracy_score(rf_prediction, y_test), 4) * 100) #percentage
accuracy_list.append(rf_accuracy)
#print("Accuracy obtained by Random Forest Classifier:", rf_accuracy)

# %% [markdown]
# # **Testing the predicted Model**

# %%
accuracy_score(y_test, rf_prediction)
# Out:
# 1.0

# %% [markdown]
# # **Classification Report**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(classification_report(y_test, rf_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#            1       1.00      1.00      1.00        74
#            2       1.00      1.00      1.00        91
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %% [markdown]
# # **Confusion Matrix**

# %%
cm = confusion_matrix(y_test, rf_prediction)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# # **NB**

# %%
#@title
# Naive Bayes Classifier
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
nb_prediction = nb_model.predict(X_test)
nb_accuracy = (round(accuracy_score(nb_prediction, y_test), 4) * 100) 
accuracy_list.append(nb_accuracy)
#print("Accuracy obtained by Naive Bayes Classifier:", nb_accuracy)

# %% [markdown]
# # **Testing the predicted Model**

# %%
accuracy_score(y_test, nb_prediction)
# Out:
# 0.78

# %% [markdown]
# # **Classification Report**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(classification_report(y_test, nb_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.88      0.80        85
#            1       0.73      0.50      0.59        74
#            2       0.86      0.91      0.89        91
#
#     accuracy                           0.78       250
#    macro avg       0.77      0.76      0.76       250
# weighted avg       0.78      0.78      0.77       250

# %% [markdown]
# # **Confusion Matrix**

# %%
cm = confusion_matrix(y_test, nb_prediction)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# # **Accuracy List of all models as [SVM, KNN, NB, RF, DT]**

# %%
accuracy_list
# Out:
# [100.0, 100.0, 77.2, 100.0, 78.0]

# %%
models = ['SVC', 'KNearestNeighbors','Decision Tree','Random Forest','Naive Bayes']

# %%
fig, ax=plt.subplots(figsize=(12,7))
plot=sns.barplot(x=models, y=accuracy_list, palette='viridis',linewidth=0.5, saturation=2)
#plt.figure(figsize=(12,7))
#ax = sns.barplot(x=models, y=accuracy_list, width= 0.9, align='center', color='cyan', edgecolor = 'red')
plt.xlabel("Classifiers", fontsize=15)
plt.ylabel("accuracy (%)", fontsize=15)
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x = p.get_x()
    y = p.get_y()
    ax.annotate(f"{height} %", (x + width/2, y+ height*1.01), ha="center")
plt.show()

# %% [markdown]
# # **Pie graph of models.**

# %%
# Create a set of colors
colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897','#FEE3EC']

# Use it thanks to the color argument
plt.pie(accuracy_list, labels=models, labeldistance=1.15, wedgeprops = { 'linewidth' : 2, 'edgecolor' : 'white' }, colors=colors);

# %% [markdown]
# # **Models and Accuarcy in ascending table**

# %%
# Accuracies of models

results = {'models' :['SVC', 'KNearestNeighbors','Decision Tree','Random Forest','Naive Bayes'],
           'accuracy' : [svc_accuracy, knn_accuracy, dt_accuracy, rf_accuracy, nb_accuracy]}

results = pd.DataFrame(results).sort_values('accuracy', ignore_index=True, ascending=False)
results.accuracy = results.accuracy.round(2)
results
# Out:
#               models  accuracy
# 0                SVC     100.0
# 1  KNearestNeighbors     100.0
# 2      Random Forest     100.0
# 3        Naive Bayes      78.0
# 4      Decision Tree      77.2

# %%
import plotly.express as px

# %%
fig = px.line(results,
            x = results.models,
            y = results.accuracy,
            text=results.accuracy,
        )
fig.update_traces(textposition = 'top right')
fig.update_layout(title = 'Models vs Accuracy',
                  plot_bgcolor = '#f9faed')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a80065ca-2a84-452e-a7b5-3643eccd4835" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a80065ca-2a84-452e-a7b5-3643eccd4835")) {
#                     Plotly.newPlot(
#                         'a80065ca-2a84-452e-a7b5-3643eccd4835',
# ...

# %% [markdown]
# So, here we can say that three models SVC, KNN and RF are best with acuuracy.

# %% [markdown]
# After SVC, KNN and RFC almost giving 100% results.
# To get more accuracy, we trained all supervised classification algorithms but you can try out a few of them which are always popular. After training all algorithms, we found that DesicionTree classifiers, Naive Bayes are given less accuracy than others.
